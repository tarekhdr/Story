# %% [markdown]
# <a href="https://colab.research.google.com/github/tarekhdr/Story/blob/master/Google_Play_Store_App_Analytics_(start).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, we will do a comprehensive analysis of the Android app market by comparing thousands of apps in the Google Play store.

# %% [markdown]
# # About the Dataset of Google Play Store Apps & Reviews

# %% [markdown]
# **Data Source:** <br>
# App and review data was scraped from the Google Play Store by Lavanya Gupta in 2018. Original files listed [here](
# https://www.kaggle.com/lava18/google-play-store-apps).

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import plotly.express as px
import plotly.graph_objects as go

# %% [markdown]
# # Notebook Presentation

# %%
# Show numeric output in decimal format e.g., 2.15
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# # Read the Dataset

# %%
df_apps = pd.read_csv('apps.csv')

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# **Challenge**: How many rows and columns does `df_apps` have? What are the column names? Look at a random sample of 5 different rows with [.sample()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.sample.html).

# %%
df_apps.shape
# Out:
# (10841, 12)

# %%
df_apps.columns
# Out:
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size_MBs', 'Installs', 'Type',
#        'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Android_Ver'],
#       dtype='object')

# %%
df_apps.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres  \
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business
#
#      Last_Updated         Android_Ver
# ...

# %%
df_apps.sample(n=5)
# Out:
#                                  App         Category  Rating  Reviews  \
# 6818   No.Diamond – Colors by Number           FAMILY    4.60     9016
# 10503    Backgrounds HD (Wallpapers)  PERSONALIZATION    4.60  2390099
# 2087     BA Pro Financial Calculator          FINANCE    2.40       36
# 4781                ES File Explorer            TOOLS    4.10      278
# 1981              Blackjack aj Poker             GAME    3.80        8
#
#        Size_MBs     Installs  Type  Price Content_Rating  \
# 6818      24.00    1,000,000  Free      0       Everyone
# 10503      6.15  100,000,000  Free      0           Teen
# 2087       9.40        1,000  Paid  $1.99       Everyone
# 4781       2.80      100,000  Free      0       Everyone
# 1981       4.20        1,000  Free      0           Teen
#
#                          Genres       Last_Updated         Android_Ver
# 6818   Entertainment;Creativity     August 6, 2018          4.1 and up
# ...

# %% [markdown]
# ### Drop Unused Columns
#
# **Challenge**: Remove the columns called `Last_Updated` and `Android_Version` from the DataFrame. We will not use these columns.

# %%
df_apps.drop(['Last_Updated', 'Android_Ver'], inplace=True, axis=1, )

# %%
df_apps.tail()
# Out:
#                   App Category  Rating   Reviews  Size_MBs       Installs  \
# 10836  Subway Surfers     GAME    4.50  27723193     76.00  1,000,000,000
# 10837  Subway Surfers     GAME    4.50  27724094     76.00  1,000,000,000
# 10838  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10839  Subway Surfers     GAME    4.50  27725352     76.00  1,000,000,000
# 10840  Subway Surfers     GAME    4.50  27711703     76.00  1,000,000,000
#
#        Type Price Content_Rating  Genres
# 10836  Free     0   Everyone 10+  Arcade
# 10837  Free     0   Everyone 10+  Arcade
# 10838  Free     0   Everyone 10+  Arcade
# 10839  Free     0   Everyone 10+  Arcade
# 10840  Free     0   Everyone 10+  Arcade

# %% [markdown]
# ### Find and Remove NaN values in Ratings
#
# **Challenge**: How may rows have a NaN value (not-a-number) in the Ratings column? Create DataFrame called `df_apps_clean` that does not include these rows.

# %%
nan_rows = df_apps[df_apps.Rating.isna()]
nan_rows.head()
# Out:
#                                             App         Category  Rating  \
# 0                       Ak Parti Yardım Toplama           SOCIAL     NaN
# 1                    Ain Arabic Kids Alif Ba ta           FAMILY     NaN
# 2  Popsicle Launcher for Android P 9.0 launcher  PERSONALIZATION     NaN
# 3                     Command & Conquer: Rivals           FAMILY     NaN
# 4                                    CX Network         BUSINESS     NaN
#
#    Reviews  Size_MBs Installs  Type   Price Content_Rating           Genres
# 0        0      8.70        0  Paid  $13.99           Teen           Social
# 1        0     33.00        0  Paid   $2.99       Everyone        Education
# 2        0      5.50        0  Paid   $1.49       Everyone  Personalization
# 3        0     19.00        0   NaN       0   Everyone 10+         Strategy
# 4        0     10.00        0  Free       0       Everyone         Business

# %%
nan_rows.shape
# Out:
# (1474, 10)

# %%
df_apps.isna().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size_MBs             0
# Installs             0
# Type                 1
# Price                0
# Content_Rating       0
# Genres               0
# dtype: int64

# %%
df_apps_clean = df_apps.dropna()

# %%
df_apps_clean.shape
# Out:
# (9367, 10)

# %%
df_apps_clean.isna().sum()
# Out:
# App               0
# Category          0
# Rating            0
# Reviews           0
# Size_MBs          0
# Installs          0
# Type              0
# Price             0
# Content_Rating    0
# Genres            0
# dtype: int64

# %% [markdown]
# ### Find and Remove Duplicates
#
# **Challenge**: Are there any duplicates in data? Check for duplicates using the [.duplicated()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.duplicated.html) function. How many entries can you find for the "Instagram" app? Use [.drop_duplicates()](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop_duplicates.html) to remove any duplicates from `df_apps_clean`.

# %%
df_apps_clean.duplicated().sum()
# Out:
# 476

# %%
df_duplicated_rows = df_apps_clean[df_apps_clean.duplicated()]

# %%
df_duplicated_rows
# Out:
#                                               App            Category  Rating  \
# 946                        420 BZ Budeze Delivery             MEDICAL    5.00
# 1133                                  MouseMingle              DATING    2.70
# 1196   Cardiac diagnosis (heart rate, arrhythmia)             MEDICAL    4.40
# 1231                                 Sway Medical             MEDICAL    5.00
# 1247               Chat Kids - Chat Room For Kids              DATING    4.70
# ...                                           ...                 ...     ...
# 10802               Skype - free IM & video calls       COMMUNICATION    4.10
# 10809                                   Instagram              SOCIAL    4.50
# 10826                                Google Drive        PRODUCTIVITY    4.40
# 10832                                 Google News  NEWS_AND_MAGAZINES    3.90
# 10839                              Subway Surfers                GAME    4.50
#
# ...

# %%
df_duplicated_rows[df_duplicated_rows['App'] == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10809     0           Teen  Social

# %%
df_apps_clean[df_apps_clean['App'] == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10808  Instagram   SOCIAL    4.50  66577446      5.30  1,000,000,000  Free
# 10809  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
# 10810  Instagram   SOCIAL    4.50  66509917      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social
# 10808     0           Teen  Social
# 10809     0           Teen  Social
# 10810     0           Teen  Social

# %%
df_apps_clean = df_apps_clean.drop_duplicates(subset=['App', 'Type', 'Price'])

# %%
df_apps_clean.shape
# Out:
# (8199, 10)

# %%
df_apps_clean[df_apps_clean['App'] == 'Instagram']
# Out:
#              App Category  Rating   Reviews  Size_MBs       Installs  Type  \
# 10806  Instagram   SOCIAL    4.50  66577313      5.30  1,000,000,000  Free
#
#       Price Content_Rating  Genres
# 10806     0           Teen  Social

# %% [markdown]
# ### Remove dollar signs in Price column

# %%
df_apps_clean['Price'] = df_apps_clean['Price'].str.replace('$', '').astype(float)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_apps_clean[df_apps_clean.Type == 'Paid'].sample(n=15)
# Out:
#                                          App            Category  Rating  \
# 2303                  Koch Morse Trainer Pro       COMMUNICATION    4.60
# 3072                          G-NetTrack Pro               TOOLS    4.30
# 2849              FL Racing Manager 2018 Pro              SPORTS    4.30
# 2704                  Lollipop Launcher Plus     PERSONALIZATION    4.10
# 4526                   Dr. Panda Supermarket              FAMILY    4.20
# 354                                    LC-DB         PHOTOGRAPHY    3.00
# 3221                          I am Rich Plus              FAMILY    4.00
# 2775                           I Am Rich Pro              FAMILY    4.40
# 3389                   Acupuncture Assistant             MEDICAL    4.50
# 4533          AJ Jump: Animal Jam Kangaroos!                GAME    4.40
# 2816                                      Go     PERSONALIZATION    4.60
# 3355                     CM FILE MANAGER Pro            BUSINESS    4.20
# ...

# %% [markdown]
# # Find Highest Rated Apps
#
# **Challenge**: Identify which apps are the highest rated. What problem might you encounter if you rely exclusively on ratings alone to determine the quality of an app?

# %%
df_apps_clean.sort_values(by='Rating', ascending=False)
# Out:
#                                           App      Category  Rating  Reviews  \
# 21                        KBA-EZ Health Guide       MEDICAL    5.00        4
# 1230                             Sway Medical       MEDICAL    5.00        3
# 1227                        AJ Men's Grooming     LIFESTYLE    5.00        2
# 1224                           FK Dedinje BGD        SPORTS    5.00       36
# 1223                          CB VIDEO VISION   PHOTOGRAPHY    5.00       13
# ...                                       ...           ...     ...      ...
# 1314                              CR Magazine      BUSINESS    1.00        1
# 1932           FE Mechanical Engineering Prep        FAMILY    1.00        2
# 357                         Speech Therapy: F        FAMILY    1.00        1
# 818   Familial Hypercholesterolaemia Handbook       MEDICAL    1.00        2
# 1208                           Thistletown CI  PRODUCTIVITY    1.00        1
#
# ...

# %%
df_apps_clean.sort_values(by=['Rating', 'Reviews', 'Installs'], ascending=False)
# Out:
#                                                     App   Category  Rating  \
# 2095                                         Ríos de Fe  LIFESTYLE    5.00
# 2438  FD Calculator (EMI, SIP, RD & Loan Eligilibility)    FINANCE    5.00
# 3115                                         Oración CX  LIFESTYLE    5.00
# 2107                     Barisal University App-BU Face     FAMILY    5.00
# 2069                                         Master E.K     FAMILY    5.00
# ...                                                 ...        ...     ...
# 1271                                             MbH BM    MEDICAL    1.00
# 1314                                        CR Magazine   BUSINESS    1.00
# 240                             House party - live chat     DATING    1.00
# 357                                   Speech Therapy: F     FAMILY    1.00
# 2416                   BJ Bridge Standard American 2018       GAME    1.00
#
# ...

# %% [markdown]
# # Find 5 Largest Apps in terms of Size (MBs)
#
# **Challenge**: What's the size in megabytes (MB) of the largest Android apps in the Google Play Store. Based on the data, do you think there could be limit in place or can developers make apps as large as they please?

# %%
df_apps_clean.sort_values(by='Size_MBs', ascending=False)
# Out:
#                                   App            Category  Rating  Reviews  \
# 9942   Talking Babsy Baby: Baby Games           LIFESTYLE    4.00   140995
# 10687          Hungry Shark Evolution                GAME    4.50  6074334
# 9943            Miami crime simulator                GAME    4.00   254518
# 9944     Gangster Town: Vice District              FAMILY    4.30    65146
# 3144                       Vi Trainer  HEALTH_AND_FITNESS    3.60      124
# ...                               ...                 ...     ...      ...
# 2648      Ad Remove Plugin for App2SD        PRODUCTIVITY    4.10       66
# 5798                 ExDialer PRO Key       COMMUNICATION    4.50     5474
# 2684     My baby firework (Remove ad)              FAMILY    4.10       30
# 7966             Market Update Helper  LIBRARIES_AND_DEMO    4.10    20145
# 4696              Essential Resources  LIBRARIES_AND_DEMO    4.60      237
#
#        Size_MBs     Installs  Type  Price Content_Rating  \
# ...

# %% [markdown]
# # Find the 5 App with Most Reviews
#
# **Challenge**: Which apps have the highest number of reviews? Are there any paid apps among the top 50?

# %%
df_apps_clean.sort_values(by='Reviews', ascending=False).head(n=50)
# Out:
#                                                      App            Category  \
# 10805                                           Facebook              SOCIAL
# 10785                                 WhatsApp Messenger       COMMUNICATION
# 10806                                          Instagram              SOCIAL
# 10784           Messenger – Text and Video Chat for Free       COMMUNICATION
# 10650                                     Clash of Clans                GAME
# 10744            Clean Master- Space Cleaner & Antivirus               TOOLS
# 10835                                     Subway Surfers                GAME
# 10828                                            YouTube       VIDEO_PLAYERS
# 10746  Security Master - Antivirus, VPN, AppLock, Boo...               TOOLS
# 10584                                       Clash Royale                GAME
# 10763                                   Candy Crush Saga                GAME
# ...

# %%
df_apps_clean[df_apps_clean.Type == 'Paid'].sort_values(by='Reviews', ascending=False)
# Out:
#                                             App         Category  Rating  \
# 9220                                  Minecraft           FAMILY    4.50
# 8825                              Hitman Sniper             GAME    4.60
# 7151              Grand Theft Auto: San Andreas             GAME    4.40
# 7954                                Bloons TD 5           FAMILY    4.60
# 7988                          Where's My Water?           FAMILY    4.70
# ...                                         ...              ...     ...
# 1099  TI-84 CE Graphing Calculator Manual TI 84           FAMILY    5.00
# 1451                  Android P Style Icon Pack  PERSONALIZATION    5.00
# 504                   AP Art History Flashcards           FAMILY    5.00
# 526                  USMLE Step 2 CK Flashcards           FAMILY    5.00
# 496                       CI 174 Gray Icon Pack  PERSONALIZATION    5.00
#
#       Reviews  Size_MBs    Installs  Type  Price Content_Rating  \
# ...

# %% [markdown]
# # Plotly Pie and Donut Charts - Visualise Categorical Data: Content Ratings

# %%
content_ratings = df_apps_clean['Content_Rating'].value_counts()

# %%
content_ratings
# Out:
# Everyone           6621
# Teen                912
# Mature 17+          357
# Everyone 10+        305
# Adults only 18+       3
# Unrated               1
# Name: Content_Rating, dtype: int64

# %%
figure = px.pie(content_ratings, title="Content Ratings", names=content_ratings.index, values=content_ratings.values, labels=content_ratings.index, hole=0.6)
figure.update_traces(textposition='outside', textinfo='percent+label', textfont_size=15)
# textposition='inside'
# textinfo='percent'
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Numeric Type Conversion: Examine the Number of Installs
#
# **Challenge**: How many apps had over 1 billion (that's right - BILLION) installations? How many apps just had a single install?
#
# Check the datatype of the Installs column.
#
# Count the number of apps at each level of installations.
#
# Convert the number of installations (the Installs column) to a numeric data type. Hint: this is a 2-step process. You'll have make sure you remove non-numeric characters first.

# %%
print(df_apps_clean['Installs'].dtypes)
# Out:
# object

# %%
df_apps_clean.Installs.describe()
# Out:
# count          8199
# unique           19
# top       1,000,000
# freq           1417
# Name: Installs, dtype: object

# %%
df_apps_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8199 entries, 21 to 10835
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             8199 non-null   object
#  1   Category        8199 non-null   object
#  2   Rating          8199 non-null   float64
#  3   Reviews         8199 non-null   int64
#  4   Size_MBs        8199 non-null   float64
#  5   Installs        8199 non-null   object
#  6   Type            8199 non-null   object
#  7   Price           8199 non-null   float64
#  8   Content_Rating  8199 non-null   object
#  9   Genres          8199 non-null   object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 704.6+ KB

# %%
installations_levels = df_apps_clean[['App','Installs']].groupby(by='Installs').count()
installations_levels.sort_values(by='Installs', ascending=True)
# Out:
#                 App
# Installs
# 1                 3
# 1,000           698
# 1,000,000      1417
# 1,000,000,000    20
# 10               69
# 10,000          988
# 10,000,000      933
# 100             303
# 100,000        1096
# 100,000,000     189
# 5                 9
# 5,000           425
# 5,000,000       607
# 50               56
# 50,000          457
# 50,000,000      202
# 500             199
# 500,000         504
# 500,000,000      24

# %%
df_apps_clean['Installs'] = df_apps_clean['Installs'].str.replace(',', '')

# %%
df_apps_clean['Installs'] = pd.to_numeric(df_apps_clean['Installs'])

# %% [markdown]
# # Find the Most Expensive Apps, Filter out the Junk, and Calculate a (ballpark) Sales Revenue Estimate
#
# Let's examine the Price column more closely.
#
# **Challenge**: Convert the price column to numeric data. Then investigate the top 20 most expensive apps in the dataset.
#
# Remove all apps that cost more than $250 from the `df_apps_clean` DataFrame.
#
# Add a column called 'Revenue_Estimate' to the DataFrame. This column should hold the price of the app times the number of installs. What are the top 10 highest grossing paid apps according to this estimate? Out of the top 10 highest grossing paid apps, how many are games?

# %%
df_apps_clean[df_apps_clean.Type == 'Paid'].sort_values(by='Price', ascending=False).head(n=20)
# Out:
#                                  App   Category  Rating  Reviews  Size_MBs  \
# 3946        I'm Rich - Trump Edition  LIFESTYLE    3.60      275      7.30
# 2461              I AM RICH PRO PLUS    FINANCE    4.00       36     41.00
# 1946  I am rich (Most expensive app)    FINANCE    4.10      129      2.70
# 5765                       I am rich  LIFESTYLE    3.80     3547      1.80
# 3114                       I am Rich    FINANCE    4.30      180      3.80
# 3145              I am rich(premium)    FINANCE    3.50      472      0.94
# 3554                      💎 I'm rich  LIFESTYLE    3.80      718     26.00
# 3221                  I am Rich Plus     FAMILY    4.00      856      8.70
# 2775                   I Am Rich Pro     FAMILY    4.40      201      2.70
# 2394                      I am Rich!    FINANCE    3.80       93     22.00
# 4606               I Am Rich Premium    FINANCE    4.10     1867      4.70
# ...

# %% [markdown]
# ### The most expensive apps sub $250

# %%
df_sub_250 = df_apps_clean[df_apps_clean.Price < 250]

# %%
df_sub_250.sort_values(by='Price', ascending=False).head(20)
# Out:
#                                                     App     Category  Rating  \
# 2281                          Vargo Anesthesia Mega App      MEDICAL    4.60
# 1407                                       LTC AS Legal      MEDICAL    4.00
# 2629                                   I am Rich Person    LIFESTYLE    4.20
# 2481                            A Manual of Acupuncture      MEDICAL    3.50
# 2463                                 PTA Content Master      MEDICAL    4.20
# 2207                                           EMT PASS      MEDICAL    3.40
# 4264                            Golfshot Plus: Golf GPS       SPORTS    4.10
# 504                           AP Art History Flashcards       FAMILY    5.00
# 4772   Human Anatomy Atlas 2018: Complete 3D Human Body      MEDICAL    4.50
# 3241  Muscle Premium - Human Anatomy, Kinesiology, B...      MEDICAL    4.20
# 2119                                         NewTek NDI  PHOTOGRAPHY    3.50
# ...

# %% [markdown]
# ### Highest Grossing Paid Apps (ballpark estimate)

# %%
df_apps_clean.insert(8, 'Revenue_Estimate', df_apps_clean.Price*df_apps_clean.Installs,True)

# %%
df_apps_clean[df_apps_clean.Revenue_Estimate > 0].sample(10)
# Out:
#                                                    App          Category  \
# 5633                   Baldur's Gate: Enhanced Edition            FAMILY
# 4659                      LEGO Batman: DC Super Heroes            FAMILY
# 4827                     Mupen64Plus AE (N64 Emulator)              GAME
# 2283                                        YouCamp EU  TRAVEL_AND_LOCAL
# 6746                        Card Wars - Adventure Time            FAMILY
# 2653                      Out There Chronicles - Ep. 2            FAMILY
# 479   ap,wifi testing,iperf,ping,android,Bluetooth,tcp             TOOLS
# 2277                               Jump'N'Shoot Attack              GAME
# 898                              Ice Crush 10.000 B.C.            FAMILY
# 2645       End Anxiety Pro - Stress, Panic Attack Help           MEDICAL
#
#       Rating  Reviews  Size_MBs  Installs  Type  Price  Revenue_Estimate  \
# 5633    4.50    20101      7.80    100000  Paid   9.99        999,000.00
# ...

# %%
df_apps_clean[df_apps_clean.Revenue_Estimate > 0].sort_values(by='Revenue_Estimate', ascending=False).head(10)
# Out:
#                                 App     Category  Rating  Reviews  Size_MBs  \
# 9220                      Minecraft       FAMILY    4.50  2376564     19.00
# 5765                      I am rich    LIFESTYLE    3.80     3547      1.80
# 4606              I Am Rich Premium      FINANCE    4.10     1867      4.70
# 8825                  Hitman Sniper         GAME    4.60   408292     29.00
# 7151  Grand Theft Auto: San Andreas         GAME    4.40   348962     26.00
# 7977        Sleep as Android Unlock    LIFESTYLE    4.50    23966      0.85
# 7477            Facetune - For Free  PHOTOGRAPHY    4.40    49553     48.00
# 6594            DraStic DS Emulator         GAME    4.60    87766     12.00
# 3946       I'm Rich - Trump Edition    LIFESTYLE    3.60      275      7.30
# 3221                 I am Rich Plus       FAMILY    4.00      856      8.70
#
#       Installs  Type  Price  Revenue_Estimate Content_Rating  \
# 9220  10000000  Paid   6.99     69,900,000.00   Everyone 10+
# ...

# %%
df_apps_clean[df_apps_clean.Revenue_Estimate > 0].count()
# Out:
# App                 604
# Category            604
# Rating              604
# Reviews             604
# Size_MBs            604
# Installs            604
# Type                604
# Price               604
# Revenue_Estimate    604
# Content_Rating      604
# Genres              604
# dtype: int64

# %%
df_apps_clean[(df_apps_clean.Revenue_Estimate > 0) & (df_apps_clean.Category == 'GAME')].count()
# Out:
# App                 76
# Category            76
# Rating              76
# Reviews             76
# Size_MBs            76
# Installs            76
# Type                76
# Price               76
# Revenue_Estimate    76
# Content_Rating      76
# Genres              76
# dtype: int64

# %% [markdown]
# # Plotly Bar Charts & Scatter Plots: Analysing App Categories

# %%
df_apps_clean['Category'].nunique()
# Out:
# 33

# %%
df_apps_clean.nunique()
# Out:
# App                 8197
# Category              33
# Rating                39
# Reviews             5321
# Size_MBs             424
# Installs              19
# Type                   2
# Price                 73
# Revenue_Estimate     192
# Content_Rating         6
# Genres               114
# dtype: int64

# %%
df_apps_clean['Category'].value_counts()
# Out:
# FAMILY                 1610
# GAME                    910
# TOOLS                   719
# FINANCE                 302
# LIFESTYLE               302
# PRODUCTIVITY            301
# PERSONALIZATION         298
# MEDICAL                 292
# PHOTOGRAPHY             263
# BUSINESS                262
# SPORTS                  260
# COMMUNICATION           257
# HEALTH_AND_FITNESS      243
# NEWS_AND_MAGAZINES      204
# SOCIAL                  203
# TRAVEL_AND_LOCAL        187
# SHOPPING                180
# BOOKS_AND_REFERENCE     169
# VIDEO_PLAYERS           148
# DATING                  134
# EDUCATION               118
# MAPS_AND_NAVIGATION     118
# ENTERTAINMENT           102
# FOOD_AND_DRINK           94
# AUTO_AND_VEHICLES        73
# WEATHER                  72
# LIBRARIES_AND_DEMO       64
# HOUSE_AND_HOME           62
# ART_AND_DESIGN           61
# COMICS                   54
# PARENTING                50
# EVENTS                   45
# BEAUTY                   42
# ...

# %%
top_10_category = df_apps_clean['Category'].value_counts()[:10]

# %%
top_10_category
# Out:
# FAMILY             1610
# GAME                910
# TOOLS               719
# FINANCE             302
# LIFESTYLE           302
# PRODUCTIVITY        301
# PERSONALIZATION     298
# MEDICAL             292
# PHOTOGRAPHY         263
# BUSINESS            262
# Name: Category, dtype: int64

# %% [markdown]
# ### Vertical Bar Chart - Highest Competition (Number of Apps)

# %%
fig = px.bar(data_frame=top_10_category, x=top_10_category.index # index is the category name
             , y=top_10_category.values, title='Top 10 categories')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Horizontal Bar Chart - Most Popular Categories (Highest Downloads)

# %%
# apps_by_category_installs = df_apps_clean[['Category', 'Installs']].groupby('Category').sum()

# %%
# apps_by_category_installs.sort_values(by='Installs', ascending=False)

# %%
apps_by_category_installs = df_apps_clean.groupby(by='Category').agg({'Installs': pd.Series.sum})

# %%
apps_by_category_installs.sort_values(by='Installs', ascending=True, inplace=True)

# %%
apps_by_category_installs
# Out:
#                         Installs
# Category
# EVENTS                  15949410
# BEAUTY                  26916200
# PARENTING               31116110
# MEDICAL                 39162676
# COMICS                  44931100
# LIBRARIES_AND_DEMO      52083000
# AUTO_AND_VEHICLES       53129800
# HOUSE_AND_HOME          97082000
# ART_AND_DESIGN         114233100
# DATING                 140912410
# FOOD_AND_DRINK         211677750
# EDUCATION              352852000
# WEATHER                361096500
# FINANCE                455312400
# MAPS_AND_NAVIGATION    503267560
# LIFESTYLE              503742120
# BUSINESS               692018120
# SPORTS                1096431465
# HEALTH_AND_FITNESS    1134006220
# SHOPPING              1400331540
# PERSONALIZATION       1532352930
# BOOKS_AND_REFERENCE   1665791655
# ENTERTAINMENT         2113660000
# NEWS_AND_MAGAZINES    2369110650
# TRAVEL_AND_LOCAL      2894859300
# VIDEO_PLAYERS         3916897200
# FAMILY                4437579590
# ...

# %%
horizonal_bar = px.bar(apps_by_category_installs,
                       x=apps_by_category_installs.Installs,
                       y=apps_by_category_installs.index,
                       orientation='h',
                       title='Category Popularity',
                       width=1000,
                       height=900)

horizonal_bar.update_layout(xaxis_title='Number of Downloads', yaxis_title='Category')
horizonal_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Category Concentration - Downloads vs. Competition
#
# **Challenge**:
# * First, create a DataFrame that has the number of apps in one column and the number of installs in another:
#
# <img src=https://imgur.com/uQRSlXi.png width="350">
#
# * Then use the [plotly express examples from the documentation](https://plotly.com/python/line-and-scatter/) alongside the [.scatter() API reference](https://plotly.com/python-api-reference/generated/plotly.express.scatter.html)to create scatter plot that looks like this.
#
# <img src=https://imgur.com/cHsqh6a.png>
#
# *Hint*: Use the size, hover_name and color parameters in .scatter(). To scale the yaxis, call .update_layout() and specify that the yaxis should be on a log-scale like so: yaxis=dict(type='log')

# %%
df_apps_category_number = df_apps_clean.groupby('Category').agg({'App': pd.Series.count})

# %%
df_merged = pd.merge(apps_by_category_installs, df_apps_category_number, on='Category', how='inner')

# %%
df_merged.sort_values(by='Installs', ascending=False, inplace=True)

# %%
df_merged.head(10)
# Out:
#                        Installs   App
# Category
# GAME                13858762717   910
# COMMUNICATION       11039241530   257
# TOOLS                8099724500   719
# PRODUCTIVITY         5788070180   301
# SOCIAL               5487841475   203
# PHOTOGRAPHY          4649143130   263
# FAMILY               4437579590  1610
# VIDEO_PLAYERS        3916897200   148
# TRAVEL_AND_LOCAL     2894859300   187
# NEWS_AND_MAGAZINES   2369110650   204

# %%
df_apps_category_concentration = df_apps_clean.groupby('Category').agg({'Installs': pd.Series.sum, 'App': pd.Series.count})

# %%
df_apps_category_concentration.sort_values(by='Installs', ascending=False, inplace=True)

# %%
df_apps_category_concentration.head(10)
# Out:
#                        Installs   App
# Category
# GAME                13858762717   910
# COMMUNICATION       11039241530   257
# TOOLS                8099724500   719
# PRODUCTIVITY         5788070180   301
# SOCIAL               5487841475   203
# PHOTOGRAPHY          4649143130   263
# FAMILY               4437579590  1610
# VIDEO_PLAYERS        3916897200   148
# TRAVEL_AND_LOCAL     2894859300   187
# NEWS_AND_MAGAZINES   2369110650   204

# %%
figure = px.scatter(data_frame=df_apps_category_concentration,
                    x='App',
                    y='Installs',
                    title='Category Concentration',
                    color='Installs',
                    size='App',
                    hover_name=df_apps_category_concentration.index,
                    width=1000,
                    height=700
                    )
figure.update_layout(xaxis_title='Number of Apps (Lower = More concentrated)',
                     yaxis_title='Installs',
                     yaxis=dict(type='log'))
figure.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Extracting Nested Data from a Column
#
# **Challenge**: How many different types of genres are there? Can an app belong to more than one genre? Check what happens when you use .value_counts() on a column with nested values? See if you can work around this problem by using the .split() function and the DataFrame's [.stack() method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.stack.html).

# %%
df_apps_clean['Genres'].value_counts()
# Out:
# Tools                                718
# Entertainment                        471
# Education                            429
# Finance                              302
# Lifestyle                            301
#                                     ...
# Adventure;Brain Games                  1
# Travel & Local;Action & Adventure      1
# Art & Design;Pretend Play              1
# Music & Audio;Music & Video            1
# Lifestyle;Pretend Play                 1
# Name: Genres, Length: 114, dtype: int64

# %%
genres = df_apps_clean['Genres'].sort_values(ascending=True).unique()
print(f'the total list number of genres is {len(genres)}')
# Out:
# the total list number of genres is 114

# %%
number_of_semicolons = 0
max_number_of_semicolons = 0

for genre in genres:
  number_of_semicolons = genre.count(';')
  if number_of_semicolons > max_number_of_semicolons:
    max_number_of_semicolons = number_of_semicolons
  print(genre)

print(f'The maximum number of semicolons in genre is {max_number_of_semicolons}')
# Out:
# Action
# Action;Action & Adventure
# Adventure
# Adventure;Action & Adventure
# Adventure;Brain Games
# Adventure;Education
# Arcade
# Arcade;Action & Adventure
# Arcade;Pretend Play
# Art & Design
# Art & Design;Creativity
# Art & Design;Pretend Play
# Auto & Vehicles
# Beauty
# Board
# Board;Action & Adventure
# Board;Brain Games
# Board;Pretend Play
# Books & Reference
# Books & Reference;Education
# Business
# Card
# Card;Action & Adventure
# Card;Brain Games
# Casino
# Casual
# Casual;Action & Adventure
# Casual;Brain Games
# Casual;Creativity
# Casual;Education
# Casual;Music & Video
# Casual;Pretend Play
# Comics
# Comics;Creativity
# Communication
# Communication;Creativity
# Dating
# Education
# Education;Action & Adventure
# Education;Brain Games
# Education;Creativity
# Education;Education
# Education;Music & Video
# Education;Pretend Play
# Educational
# Educational;Action & Adventure
# Educational;Brain Games
# Educational;Creativity
# Educational;Education
# ...

# %%
all_genres = []
semicolon = ";"
for genre in genres:
  if semicolon in genre:
    multi_genre = genre.split(semicolon)
    for term in multi_genre:
      all_genres.append(term)
  else:
    all_genres.append(genre)

print(f'The number of different types of genres are: {len(all_genres)}')

all_genres.sort

for genre in all_genres:
  print(genre)

all_genres_unique = list(set(all_genres))

print(f'The number of unique different types of genres are: {len(all_genres_unique)}')

for genre in all_genres_unique:
  print(genre)
# Out:
# The number of different types of genres are: 181
# Action
# Action
# Action & Adventure
# Adventure
# Adventure
# Action & Adventure
# Adventure
# Brain Games
# Adventure
# Education
# Arcade
# Arcade
# Action & Adventure
# Arcade
# Pretend Play
# Art & Design
# Art & Design
# Creativity
# Art & Design
# Pretend Play
# Auto & Vehicles
# Beauty
# Board
# Board
# Action & Adventure
# Board
# Brain Games
# Board
# Pretend Play
# Books & Reference
# Books & Reference
# Education
# Business
# Card
# Card
# Action & Adventure
# Card
# Brain Games
# Casino
# Casual
# Casual
# Action & Adventure
# Casual
# Brain Games
# Casual
# Creativity
# Casual
# Education
# Casual
# Music & Video
# Casual
# Pretend Play
# Comics
# Comics
# Creativity
# Communication
# Communication
# Creativity
# Dating
# Education
# Education
# Action & Adventure
# Education
# Brain Games
# Education
# Creativity
# Education
# Education
# Education
# Music & Video
# Education
# Pretend Play
# Educational
# Educational
# ...

# %%
# split the strings in the Genres column based on semicolon separator and then .stack them
stack = df_apps_clean.Genres.str.split(';', expand=True).stack()
print(stack)
print(f'We now have a single column with shape: {stack.shape}')
num_genres = stack.value_counts()
print(f'Number of genres: {len(num_genres)}')
# Out:
# 21     0                    Medical
# 28     0                     Arcade
# 47     0                     Arcade
# 82     0                     Arcade
# 99     0                    Medical
#                      ...
# 10824  0               Productivity
# 10828  0    Video Players & Editors
# 10829  0    Video Players & Editors
# 10831  0           News & Magazines
# 10835  0                     Arcade
# Length: 8579, dtype: object
# We now have a single column with shape: (8579,)
# Number of genres: 53

# %%
num_genres
# Out:
# Tools                      719
# Education                  587
# Entertainment              502
# Action                     304
# Lifestyle                  303
# Finance                    302
# Productivity               301
# Personalization            298
# Medical                    292
# Sports                     270
# Photography                263
# Business                   262
# Communication              258
# Health & Fitness           245
# Casual                     216
# News & Magazines           204
# Social                     203
# Simulation                 200
# Travel & Local             187
# Arcade                     185
# Shopping                   180
# Books & Reference          171
# Video Players & Editors    150
# Dating                     134
# Puzzle                     124
# Maps & Navigation          118
# Role Playing               111
# Racing                     103
# Action & Adventure          96
# Strategy                    95
# ...

# %% [markdown]
# # Colour Scales in Plotly Charts - Competition in Genres

# %% [markdown]
# **Challenge**: Can you create this chart with the Series containing the genre data?
#
# <img src=https://imgur.com/DbcoQli.png width=400>
#
# Try experimenting with the built in colour scales in Plotly. You can find a full list [here](https://plotly.com/python/builtin-colorscales/).
#
# * Find a way to set the colour scale using the color_continuous_scale parameter.
# * Find a way to make the color axis disappear by using coloraxis_showscale.

# %%
genres_bar_chart = px.bar(data_frame=num_genres[:16],
                          x=num_genres.index[:16], # index is the genre name
                          y=num_genres.values[:16],                          
                          title='Top Genres',
                          hover_name=num_genres.index[:16],
                          color=num_genres.values[:16],
                          color_continuous_scale='Agsunset'
                          )
genres_bar_chart.update_layout(xaxis_title='Genre', yaxis_title='Number of Apps', coloraxis_showscale=False)
genres_bar_chart.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Grouped Bar Charts: Free vs. Paid Apps per Category

# %%
df_apps_clean['Type'].value_counts()
# Out:
# Free    7595
# Paid     604
# Name: Type, dtype: int64

# %%
df_apps_categories_types = df_apps_clean.groupby(['Category', 'Type'], as_index=False).agg({'App': pd.Series.count})

# %%
df_apps_categories_types
# Out:
#              Category  Type  App
# 0      ART_AND_DESIGN  Free   58
# 1      ART_AND_DESIGN  Paid    3
# 2   AUTO_AND_VEHICLES  Free   72
# 3   AUTO_AND_VEHICLES  Paid    1
# 4              BEAUTY  Free   42
# ..                ...   ...  ...
# 56   TRAVEL_AND_LOCAL  Paid    8
# 57      VIDEO_PLAYERS  Free  144
# 58      VIDEO_PLAYERS  Paid    4
# 59            WEATHER  Free   65
# 60            WEATHER  Paid    7
#
# [61 rows x 3 columns]

# %%
df_apps_categories_types.shape
# Out:
# (61, 3)

# %% [markdown]
# **Challenge**: Use the plotly express bar [chart examples](https://plotly.com/python/bar-charts/#bar-chart-with-sorted-or-ordered-categories) and the [.bar() API reference](https://plotly.com/python-api-reference/generated/plotly.express.bar.html#plotly.express.bar) to create this bar chart:
#
# <img src=https://imgur.com/LE0XCxA.png>
#
# You'll want to use the `df_free_vs_paid` DataFrame that you created above that has the total number of free and paid apps per category.
#
# See if you can figure out how to get the look above by changing the `categoryorder` to 'total descending' as outlined in the documentation here [here](https://plotly.com/python/categorical-axes/#automatically-sorting-categories-by-name-or-total-value).

# %%
g_bar = px.bar(data_frame=df_apps_categories_types,
               x='Category',
               y='App',
               title='Free vs Paid Apps by Category',
               color='Type',
               barmode='group')

g_bar.update_layout(xaxis_title='Category', yaxis_title='Number of Apps', xaxis={'categoryorder':'total descending'}, yaxis=dict(type='log'))
g_bar.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Lost Downloads for Paid Apps
#
# **Challenge**: Create a box plot that shows the number of Installs for free versus paid apps. How does the median number of installations compare? Is the difference large or small?
#
# Use the [Box Plots Guide](https://plotly.com/python/box-plots/) and the [.box API reference](https://plotly.com/python-api-reference/generated/plotly.express.box.html) to create the following chart.
#
# <img src=https://imgur.com/uVsECT3.png>

# %%
box_plot = px.box(data_frame=df_apps_clean,
                  x='Type',
                  y='Installs',
                  color='Type',
                  notched=True,
                  points='all',
                  title='How many downloads are paid apps giving up?',
                  height=800,
                  width=1100)
box_plot.update_layout(yaxis=dict(type='log'))
box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Plotly Box Plots: Revenue by App Category
#
# **Challenge**: See if you can generate the chart below:
#
# <img src=https://imgur.com/v4CiNqX.png>
#
# Looking at the hover text, how much does the median app earn in the Tools category? If developing an Android app costs $30,000 or thereabouts, does the average photography app recoup its development costs?
#
# Hint: I've used 'min ascending' to sort the categories.

# %%
df_paid_apps = df_apps_clean[df_apps_clean.Type == 'Paid']
box_plot = px.box(data_frame=df_paid_apps,
                  x='Category',
                  y='Revenue_Estimate',                  
                  title='How much can paid apps earn?',
                  height=800,
                  width=1400)
box_plot.update_layout(xaxis_title='Category',
                       yaxis_title='Paid App Ballpark Revenue',
                       xaxis={'categoryorder':'min ascending'}, yaxis=dict(type='log'))
box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # How Much Can You Charge? Examine Paid App Pricing Strategies by Category
#
# **Challenge**: What is the median price for a paid app? Then compare pricing by category by creating another box plot. But this time examine the prices (instead of the revenue estimates) of the paid apps. I recommend using `{categoryorder':'max descending'}` to sort the categories.

# %%
df_paid_apps.Price.median()
# Out:
# 2.99

# %%
df_paid_apps.Price.mean()
# Out:
# 14.083609271523182

# %%
df_apps_prices_medians = df_apps_clean[df_apps_clean.Type == 'Paid']
df_apps_prices_medians = df_apps_prices_medians[['Category', 'Price']].groupby('Category').agg({'Price': pd.Series.median})

# %%
df_apps_prices_medians

# %%
box_plot = px.box(data_frame=df_paid_apps,
                  x='Category',
                  y='Price',                  
                  title='How much can you charge? Price Per Category',
                  height=800,
                  width=1400)
box_plot.update_layout(xaxis_title='Category',
                       yaxis_title='Paid App Price',
                       xaxis={'categoryorder':'max descending'}, yaxis=dict(type='log'))
box_plot.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
